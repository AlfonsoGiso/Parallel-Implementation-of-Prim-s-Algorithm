# %%
# !lsb_release --all
# !nvcc --version
# !nvidia-smi
# !cat /proc/cpuinfo
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.3 LTS
# Release:	22.04
# Codename:	jammy
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Sat Jan 13 10:25:08 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/ColabNotebooks/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/ColabNotebooks

# %%
# !gcc -o graphGenerator graphGenerator.c

# %%
# %cd /content/gdrive/MyDrive/ColabNotebooks/
# Out:
# /content/gdrive/MyDrive/ColabNotebooks

# %%
# !gcc -o PrimMST PrimMST.c

# %%
# !./graphGenerator 500 prova.txt

# %%
# !./PrimMST prova.txt 500
# Out:
# Sequential Time : 0.143180
# Total weigth: 0

# %%
#!nvcc -o PrimCUDAOpenMPv1 PrimCUDAOpenMPv1.cu
# !export OMP_NUM_THREADS=2
# !nvcc -Xcompiler  -fopenmp PrimCUDAOpenMPv1.cu -o PrimCUDAOpenMPv1
#!nvprof --print-gpu-trace ./PrimCUDAOpenMPv1 --benchmark

# %%
# !./PrimCUDAOpenMPv1 prova.txt 500
# Out:
# Edge count:53313
# Block count:2
# Iteration:0 Time0.228979
# Iteration:1 Time0.157903
# Iteration:2 Time0.123140
# Iteration:3 Time0.113388
# Iteration:4 Time0.108252
# Iteration:5 Time0.111226
# Iteration:6 Time0.107477
# Iteration:7 Time0.099064
# Iteration:8 Time0.096838
# Iteration:9 Time0.109531
# CUDA Time : 0.125580

# %%
# !python3 execute.py

# %%
# !python plot_cuda_graph.py 500
